-- %%
CREATE CATALOG IF NOT EXISTS marathon;
CREATE SCHEMA IF NOT EXISTS marathon.bronze;
CREATE SCHEMA IF NOT EXISTS marathon.silver;
CREATE SCHEMA IF NOT EXISTS marathon.gold;

DROP TABLE IF EXISTS marathos.default.results_raw;

DROP TABLE IF EXISTS marathos.bronze.results_obt;
