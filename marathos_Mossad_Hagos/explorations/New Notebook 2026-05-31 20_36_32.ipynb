# %%
df = spark.read.csv(
    "/Volumes/marathos/default/marathos_raw/raw/TWO_CENTURIES_OF_UM_RACES.csv",
    header=True,
    inferSchema=True,

)
df.printSchema()
df.show(5, truncate = False)
print("rows:", df.count(), "cols:", len(df.columns))
